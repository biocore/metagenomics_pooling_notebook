# %%
# %reload_ext watermark
# %matplotlib inline
import numpy as np
import pandas as pd

def rc(seq):
    """
    from http://stackoverflow.com/a/25189185/7146785
    """
    complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A'}
    
    rev_seq = "".join(complement.get(base, base) for base in reversed(seq))
    
    return(rev_seq)
# %watermark -i -v -iv -m -h -p metapool,sample_sheet,openpyxl -u
# Out:
# Last updated: 2021-12-15T17:25:06.558094-06:00
#
# Python implementation: CPython
# Python version       : 3.9.7
# IPython version      : 7.30.1
#
# metapool    : 0+untagged.112.g8fed443.dirty
# sample_sheet: 0.12.0
# openpyxl    : 3.0.9
#
# Compiler    : Clang 10.0.0
# OS          : Darwin
# Release     : 20.6.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 12
# Architecture: 64bit
#
# Hostname: Kelly-Fogelsons-MacBook-Pro.local
#
# pandas: 1.3.4
# numpy : 1.21.2

# %% [markdown]
# ## Import plate map from IDT

# %%
row_offset = 0
col_offset = 0

print('%s%s' % (rowmod('A'), colmod('1')))
print('%s%s' % (rowmod('H'), colmod('12')))

row_offset = 0
col_offset = 1

print('%s%s' % (rowmod('A'), colmod('1')))
print('%s%s' % (rowmod('H'), colmod('12')))


row_offset = 1
col_offset = 0

print('%s%s' % (rowmod('A'), colmod('1')))
print('%s%s' % (rowmod('H'), colmod('12')))


row_offset = 1
col_offset = 1

print('%s%s' % (rowmod('A'), colmod('1')))
print('%s%s' % (rowmod('H'), colmod('12')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9g/k400z9fd3l3fgqsww52j2zn40000gp/T/ipykernel_17628/2411283702.py in <module>
#       2 col_offset = 0
#       3
# ----> 4 print('%s%s' % (rowmod('A'), colmod('1')))
#       5 print('%s%s' % (rowmod('H'), colmod('12')))
#       6
#
# NameError: name 'rowmod' is not defined

# %%
def condense_plates(input_df, plate_names, plate_col, row_col, col_col):
    
    df = input_df.copy()

    df['condensed row'] = np.nan
    df['condensed col'] = np.nan
    
    rowmod = lambda x: chr((ord(x.upper()) - 65) * 2 + row_offset + 65)
    colmod = lambda x: int((int(x) - 1) * 2 + 1 + col_offset)
    
    if len(plate_names) > 4:
        raise ValueError('Too many plates! Provide up to 4.')

    for i, plate in enumerate(plate_names):
        row_offset = int(np.floor(i/2))
        col_offset = i % 2
        
        df.loc[df[plate_col] == plate, 'condensed row'] = df.loc[df[plate_col] == plate, row_col].apply(rowmod)
        df.loc[df[plate_col] == plate, 'condensed col'] = df.loc[df[plate_col] == plate, col_col].apply(colmod)
    
    df['condensed col'] = df['condensed col'].astype(int)
    return(df)

# %%
# read in IDT plate map
idt_map = pd.read_excel('./test_data/iTru/Plate_Specs_iTru5_96-1-4_iTru7_96-1-4_OnePerPlate_Dec_2017.xlsx')
idt_map.dropna(thresh=3, inplace=True)

# split row and column from 96-well format
idt_map['origin row'] = idt_map['Well Position'].str[0]
idt_map['origin col'] = idt_map['Well Position'].str[1:].astype(int)

# %%
# add 384-plate positions to i7 plate
idt_map_i7 = condense_plates(idt_map.loc[idt_map['Sequence Name'].str.startswith('iTru7'),],
                ['iTru7_plate_96-1 REPLICATE','iTru7_plate_96-2 REPLICATE',
                 'iTru7_plate_96-3 REPLICATE','iTru7_plate_96-4 REPLICATE'],
                'Plate Name',
                'origin row',
                'origin col').reset_index(drop=True)

# add 384-plate positions to i5 plate
idt_map_i5 = condense_plates(idt_map.loc[idt_map['Sequence Name'].str.startswith('iTru5'),],
                ['iTru5_plate_96-1 REPLICATE','iTru5_plate_96-2 REPLICATE',
                 'iTru5_plate_96-3 REPLICATE','iTru5_plate_96-4 REPLICATE'],
                'Plate Name',
                'origin row',
                'origin col').reset_index(drop=True)

# %%
idt_map_i5.head()
# Out:
#                    Plate Name  Plate Barcode Well Position Sequence Name  \
# 0  iTru5_plate_96-1 REPLICATE     11505386.0           A01    iTru5_01_A
# 1  iTru5_plate_96-1 REPLICATE     11505386.0           A02    iTru5_02_A
# 2  iTru5_plate_96-1 REPLICATE     11505386.0           A03    iTru5_03_A
# 3  iTru5_plate_96-1 REPLICATE     11505386.0           A04    iTru5_04_A
# 4  iTru5_plate_96-1 REPLICATE     11505386.0           A05    iTru5_05_A
#
#                                             Sequence  Manufacturing ID  \
# 0  AAT GAT ACG GCG ACC ACC GAG ATC TAC ACA CCG AC...       231436960.0
# 1  AAT GAT ACG GCG ACC ACC GAG ATC TAC ACC TTC GC...       231436948.0
# 2  AAT GAT ACG GCG ACC ACC GAG ATC TAC ACA ACA CC...       231436936.0
# 3  AAT GAT ACG GCG ACC ACC GAG ATC TAC ACC GTA TC...       231436924.0
# 4  AAT GAT ACG GCG ACC ACC GAG ATC TAC ACG GTA CG...       231436912.0
#
#    Measured Molecular Weight  Calculated Molecular Weight  OD260  nmoles  \
# 0                        0.0                      15815.0   0.62    1.25
# 1                        0.0                      15797.0   0.61    1.25
# 2                        0.0                      15775.0   0.62    1.25
# 3                        0.0                      15788.0   0.61    1.25
# 4                        0.0                      15886.0   0.63    1.25
#
#      µg  Measured Concentration µM   Final Volume µL   \
# 0  20.0                       125.0              10.0
# 1  20.0                       125.0              10.0
# 2  20.0                       125.0              10.0
# 3  20.0                       125.0              10.0
# 4  20.0                       125.0              10.0
#
#    Extinction Coefficient L/(mole·cm)    Tm origin row  origin col  \
# 0                            497600.0  69.0          A           1
# 1                            488000.0  69.0          A           2
# 2                            494700.0  69.0          A           3
# 3                            487900.0  69.0          A           4
# 4                            500900.0  69.0          A           5
#
#   condensed row  condensed col
# 0             A              1
# 1             A              3
# 2             A              5
# 3             A              7
# 4             A              9

# %%
idt_map_i7.head()
# Out:
#                    Plate Name  Plate Barcode Well Position Sequence Name  \
# 0  iTru7_plate_96-1 REPLICATE     11505512.0           A01  iTru7_101_01
# 1  iTru7_plate_96-1 REPLICATE     11505512.0           A02  iTru7_101_02
# 2  iTru7_plate_96-1 REPLICATE     11505512.0           A03  iTru7_101_03
# 3  iTru7_plate_96-1 REPLICATE     11505512.0           A04  iTru7_101_04
# 4  iTru7_plate_96-1 REPLICATE     11505512.0           A05  iTru7_101_05
#
#                                             Sequence  Manufacturing ID  \
# 0  CAA GCA GAA GAC GGC ATA CGA GAT GGT AAC GTG TG...       231436232.0
# 1  CAA GCA GAA GAC GGC ATA CGA GAT CAA CAC AGG TG...       231436231.0
# 2  CAA GCA GAA GAC GGC ATA CGA GAT ACA CCT CAG TG...       231436229.0
# 3  CAA GCA GAA GAC GGC ATA CGA GAT CAT GGA TCG TG...       231436228.0
# 4  CAA GCA GAA GAC GGC ATA CGA GAT TGA TAG GCG TG...       231436226.0
#
#    Measured Molecular Weight  Calculated Molecular Weight  OD260  nmoles  \
# 0                        0.0                      14667.0   0.60    1.25
# 1                        0.0                      14605.0   0.60    1.25
# 2                        0.0                      14556.0   0.59    1.25
# 3                        0.0                      14627.0   0.60    1.25
# 4                        0.0                      14667.0   0.60    1.25
#
#      µg  Measured Concentration µM   Final Volume µL   \
# 0  18.0                         0.0               0.0
# 1  18.0                         0.0               0.0
# 2  18.0                         0.0               0.0
# 3  18.0                         0.0               0.0
# 4  18.0                         0.0               0.0
#
#    Extinction Coefficient L/(mole·cm)    Tm origin row  origin col  \
# 0                            478700.0  68.0          A           1
# 1                            480100.0  68.0          A           2
# 2                            473900.0  68.0          A           3
# 3                            476200.0  68.0          A           4
# 4                            478500.0  68.0          A           5
#
#   condensed row  condensed col
# 0             A              1
# 1             A              3
# 2             A              5
# 3             A              7
# 4             A              9

# %%
# cut down to columns used for sample sheet: i5

idt_map_i5['Primer Index Sequence'] = idt_map_i5['Sequence'].str.replace(' ','').str[29:37]
idt_map_i5['count'] = idt_map_i5.index + 1

i5 = idt_map_i5.loc[:,['count', 'Sequence Name', 'Primer Index Sequence', 'Plate Name', 'origin row', 'origin col', 'condensed row', 'condensed col']]
i5['MiSeq & HiSeq Index Sequence'] = i5['Primer Index Sequence']
i5['MiniSeq & NextSeq Index Sequence'] = i5['Primer Index Sequence'].apply(rc)

i5 = i5.loc[:,['count', 'Sequence Name', 'Primer Index Sequence', 'MiSeq & HiSeq Index Sequence', 'MiniSeq & NextSeq Index Sequence',
         'Plate Name', 'origin row', 'origin col', 'condensed row', 'condensed col']]

i5.rename(columns={'Sequence Name': 'Primer Name', 'condensed row': 'Row', 'condensed col': 'Col'}, inplace=True)

i5.head()
# Out:
#    count Primer Name Primer Index Sequence MiSeq & HiSeq Index Sequence  \
# 0      1  iTru5_01_A              ACCGACAA                     ACCGACAA
# 1      2  iTru5_02_A              CTTCGCAA                     CTTCGCAA
# 2      3  iTru5_03_A              AACACCAC                     AACACCAC
# 3      4  iTru5_04_A              CGTATCTC                     CGTATCTC
# 4      5  iTru5_05_A              GGTACGAA                     GGTACGAA
#
#   MiniSeq & NextSeq Index Sequence                  Plate Name origin row  \
# 0                         TTGTCGGT  iTru5_plate_96-1 REPLICATE          A
# 1                         TTGCGAAG  iTru5_plate_96-1 REPLICATE          A
# 2                         GTGGTGTT  iTru5_plate_96-1 REPLICATE          A
# 3                         GAGATACG  iTru5_plate_96-1 REPLICATE          A
# 4                         TTCGTACC  iTru5_plate_96-1 REPLICATE          A
#
#    origin col Row  Col
# 0           1   A    1
# 1           2   A    3
# 2           3   A    5
# 3           4   A    7
# 4           5   A    9

# %%
# cut down to columns used for sample sheet: i5=7

idt_map_i7['Primer Index Sequence'] = idt_map_i7['Sequence'].str.replace(' ','').str[24:32].apply(rc)
idt_map_i7['count'] = idt_map_i7.index + 1

i7 = idt_map_i7.loc[:,['count', 'Sequence Name', 'Primer Index Sequence', 'Plate Name', 'origin row', 'origin col', 'condensed row', 'condensed col']]

i7 = i7.loc[:,['count', 'Sequence Name', 'Primer Index Sequence',
         'Plate Name', 'origin row', 'origin col', 'condensed row', 'condensed col']]

i7.rename(columns={'Sequence Name': 'Primer Name', 'condensed row': 'Row', 'condensed col': 'Col'}, inplace=True)

i7.head()
# Out:
#    count   Primer Name Primer Index Sequence                  Plate Name  \
# 0      1  iTru7_101_01              ACGTTACC  iTru7_plate_96-1 REPLICATE
# 1      2  iTru7_101_02              CTGTGTTG  iTru7_plate_96-1 REPLICATE
# 2      3  iTru7_101_03              TGAGGTGT  iTru7_plate_96-1 REPLICATE
# 3      4  iTru7_101_04              GATCCATG  iTru7_plate_96-1 REPLICATE
# 4      5  iTru7_101_05              GCCTATCA  iTru7_plate_96-1 REPLICATE
#
#   origin row  origin col Row  Col
# 0          A           1   A    1
# 1          A           2   A    3
# 2          A           3   A    5
# 3          A           4   A    7
# 4          A           5   A    9

# %%
# write to excel

writer = pd.ExcelWriter('./test_data/iTru/new_iTru_index_list_Dec2017.xlsx')
i5.to_excel(writer,'iTru5')
i7.to_excel(writer,'iTru7')
writer.save()

# %%
# i5 = pd.read_excel('./test_data/iTru/new_iTru_index_list.xlsx',
#                sheetname='iTru5')

# i7 = pd.read_excel('./test_data/iTru/new_iTru_index_list.xlsx',
#                sheetname='iTru7')

# %%
i5.head()
# Out:
#    count Primer Name Primer Index Sequence MiSeq & HiSeq Index Sequence  \
# 0      1  iTru5_01_A              ACCGACAA                     ACCGACAA
# 1      2  iTru5_02_A              CTTCGCAA                     CTTCGCAA
# 2      3  iTru5_03_A              AACACCAC                     AACACCAC
# 3      4  iTru5_04_A              CGTATCTC                     CGTATCTC
# 4      5  iTru5_05_A              GGTACGAA                     GGTACGAA
#
#   MiniSeq & NextSeq Index Sequence                  Plate Name origin row  \
# 0                         TTGTCGGT  iTru5_plate_96-1 REPLICATE          A
# 1                         TTGCGAAG  iTru5_plate_96-1 REPLICATE          A
# 2                         GTGGTGTT  iTru5_plate_96-1 REPLICATE          A
# 3                         GAGATACG  iTru5_plate_96-1 REPLICATE          A
# 4                         TTCGTACC  iTru5_plate_96-1 REPLICATE          A
#
#    origin col Row  Col
# 0           1   A    1
# 1           2   A    3
# 2           3   A    5
# 3           4   A    7
# 4           5   A    9

# %%
i7.head()
# Out:
#    count   Primer Name Primer Index Sequence                  Plate Name  \
# 0      1  iTru7_101_01              ACGTTACC  iTru7_plate_96-1 REPLICATE
# 1      2  iTru7_101_02              CTGTGTTG  iTru7_plate_96-1 REPLICATE
# 2      3  iTru7_101_03              TGAGGTGT  iTru7_plate_96-1 REPLICATE
# 3      4  iTru7_101_04              GATCCATG  iTru7_plate_96-1 REPLICATE
# 4      5  iTru7_101_05              GCCTATCA  iTru7_plate_96-1 REPLICATE
#
#   origin row  origin col Row  Col
# 0          A           1   A    1
# 1          A           2   A    3
# 2          A           3   A    5
# 3          A           4   A    7
# 4          A           5   A    9

# %%
combos = 384 * 384
i5_name = [''] * combos
i7_name = [''] * combos
i5_seq = [''] * combos
i7_seq = [''] * combos
i57_seq = [''] * combos
i5_well = [''] * combos
i7_well = [''] * combos
i5_plate = ['iTru5_plate'] * combos
i7_plate = ['iTru7_plate'] * combos
idx = [np.nan] * combos

i = 0
for i7_offset in range(384):
    for x in range(384):
        i5_idx = x
        i7_idx = (x + i7_offset) % 384
        idx[i] = i
        i5_name[i] = i5.iloc[i5_idx]['Primer Name']
        i7_name[i] = i7.iloc[i7_idx]['Primer Name']
        i5_seq[i] =  i5.iloc[i5_idx]['Primer Index Sequence']
        i7_seq[i] = i7.iloc[i7_idx]['Primer Index Sequence']
        i57_seq[i] = i5_seq[i] + i7_seq[i]
        i5_well[i] =  '{0}{1}'.format(i5.iloc[i5_idx]['Row'],i5.iloc[i5_idx]['Col'])
        i7_well[i] = '{0}{1}'.format(i7.iloc[i7_idx]['Row'],i7.iloc[i7_idx]['Col'])
        i += 1

index_combo_df = pd.DataFrame(np.array([idx, i57_seq, i5_name, i5_seq, i5_well, i5_plate, i7_name, i7_seq, i7_well, i7_plate]).T,
                              columns = ['index combo','index combo seq','i5 name','i5 sequence','i5 well','i5 plate',
                                         'i7 name','i7 sequence','i7 well','i7 plate'])

# %%
index_combo_df
# Out:
#        index combo   index combo seq      i5 name i5 sequence i5 well  \
# 0                0  ACCGACAAACGTTACC   iTru5_01_A    ACCGACAA      A1
# 1                1  CTTCGCAACTGTGTTG   iTru5_02_A    CTTCGCAA      A3
# 2                2  AACACCACTGAGGTGT   iTru5_03_A    AACACCAC      A5
# 3                3  CGTATCTCGATCCATG   iTru5_04_A    CGTATCTC      A7
# 4                4  GGTACGAAGCCTATCA   iTru5_05_A    GGTACGAA      A9
# ...            ...               ...          ...         ...     ...
# 147451      147451  GATTGTCCCACTAGCT  iTru5_120_H    GATTGTCC     P16
# 147452      147452  GATGCTACTGGTACAG  iTru5_121_H    GATGCTAC     P18
# 147453      147453  GAACGGTTAGCACTTC  iTru5_122_H    GAACGGTT     P20
# 147454      147454  CTCTTGTCGCATACAG  iTru5_123_H    CTCTTGTC     P22
# 147455      147455  AACGCCTTCTTAGGAC  iTru5_124_H    AACGCCTT     P24
#
#            i5 plate       i7 name i7 sequence i7 well     i7 plate
# 0       iTru5_plate  iTru7_101_01    ACGTTACC      A1  iTru7_plate
# 1       iTru5_plate  iTru7_101_02    CTGTGTTG      A3  iTru7_plate
# 2       iTru5_plate  iTru7_101_03    TGAGGTGT      A5  iTru7_plate
# 3       iTru5_plate  iTru7_101_04    GATCCATG      A7  iTru7_plate
# 4       iTru5_plate  iTru7_101_05    GCCTATCA      A9  iTru7_plate
# ...             ...           ...         ...     ...          ...
# 147451  iTru5_plate  iTru7_115_07    CACTAGCT     P14  iTru7_plate
# 147452  iTru5_plate  iTru7_115_08    TGGTACAG     P16  iTru7_plate
# 147453  iTru5_plate  iTru7_115_09    AGCACTTC     P18  iTru7_plate
# 147454  iTru5_plate  iTru7_115_10    GCATACAG     P20  iTru7_plate
# 147455  iTru5_plate  iTru7_115_11    CTTAGGAC     P22  iTru7_plate
#
# [147456 rows x 10 columns]

# %%
len(set(index_combo_df['index combo seq']))
# Out:
# 147456

# %%
index_combo_df.to_csv('./test_output/iTru/new_iTru_combos_Dec2017.csv', index=False)

# %%
# check against old list

old_index_combo_df = pd.read_csv('./test_output/iTru/new_iTru_combos.csv')

# %%
old_index_combo_df.head()
# Out:
#    index combo   index combo seq     i5 name i5 sequence i5 well     i5 plate  \
# 0            0  ACCGACAAACGTTACC  iTru5_01_A    ACCGACAA      A1  iTru5_plate
# 1            1  AGTGGCAACTGTGTTG  iTru5_01_B    AGTGGCAA      B1  iTru5_plate
# 2            2  CACAGACTTGAGGTGT  iTru5_01_C    CACAGACT      C1  iTru5_plate
# 3            3  CGACACTTGATCCATG  iTru5_01_D    CGACACTT      D1  iTru5_plate
# 4            4  GACTTGTGGCCTATCA  iTru5_01_E    GACTTGTG      E1  iTru5_plate
#
#         i7 name i7 sequence i7 well     i7 plate
# 0  iTru7_101_01    ACGTTACC      A1  iTru7_plate
# 1  iTru7_101_02    CTGTGTTG      A2  iTru7_plate
# 2  iTru7_101_03    TGAGGTGT      A3  iTru7_plate
# 3  iTru7_101_04    GATCCATG      A4  iTru7_plate
# 4  iTru7_101_05    GCCTATCA      A5  iTru7_plate

# %%
set(old_index_combo_df['index combo seq']) == set(index_combo_df['index combo seq'])
# Out:
# True
